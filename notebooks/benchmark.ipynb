# %%
import os
import sys
import pandas as pd
from tqdm.notebook import tqdm

directory = os.path.abspath('../src')
if directory not in sys.path:
    sys.path.append(directory)
    
from score_essays import score_essay_benchmark

# %%
data_directory = os.path.join(os.path.abspath(os.path.join('..')), 
                                'data',
                                'test_set_with_features.csv')
test_set = pd.read_csv(data_directory)

# %%
tqdm.pandas()
test_set['benchmark_prediction'] = test_set.progress_apply(lambda x: score_essay_benchmark(test_set, x['EssayText']), axis=1)
# Out:
#   0%|          | 0/5224 [00:00<?, ?it/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ...

# %%
benchmark_directory = os.path.join(os.path.abspath(os.path.join('..')), 
                                'data',
                                'predictions',
                                'test_set_with_benchmark_predictions.csv')
test_set.to_csv(benchmark_directory)
